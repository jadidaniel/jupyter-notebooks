# %% [markdown]
# # U.S.A. Presidential Vocabulary
#
# Whenever a United States of America president is elected or re-elected, an inauguration ceremony takes place to mark the beginning of the president’s term. During the ceremony, the president gives an inaugural address to the nation, dictating the tone and focus of the next four years of leadership.
#
# The goal of this project is to analyze the inaugural addresses of the presidents of the United States of America using word embeddings.
# By training sets of word embeddings on subsets of inaugural address versus the collection of presidents as a whole, we can learn about the different ways in which the presidents use language to convey their agenda.
#
#
# ### Preprocessing Data
#
# In order to create word embeddings on the corpus of all the presidents’ speeches, we need to read the text data from each file, separate the files into sentences on a word by word basis, and then merge all the sentences across the speeches into one big list of lists.

# %%
import os
from nltk.tokenize import PunktSentenceTokenizer
from collections import Counter
from nltk.corpus import stopwords
import gensim

# Find txt files in directory
files = sorted([file for file in os.listdir() if file[-4:] == '.txt'])
print(files)
# Out:
# ['1789-Washington.txt', '1793-Washington.txt', '1797-John-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-John-Q-Adam.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-William-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Benjamin-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Theodore-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Franklin-D-Roosevelt.txt', '1937-Franklin-D-Roosevelt.txt', '1941-Franklin-D-Roosevelt.txt', '1945-Franklin-D-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Lyndon-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan.txt', '1985-Reagan.txt', '1989-George-HW-Bush.txt', '1993-Clinton.txt', '1997-Clinton.txt', '2001-George-W-Bush.txt', '2005-George-W-Bush.txt', '2009-Obama.txt', '2013-Obama.txt', '2017-Trump.txt']

# %%
def read_file(file_name):
  with open(file_name, 'r+', encoding='utf-8') as file:
    file_text = file.read()
  return file_text

# %%
# Upload files to speaches list
speeches = [read_file(file) for file in files]
# Print 1 sentence of the 1st speech
speeches[0][0:278]
# Out:
# 'Fellow-Citizens of the Senate and of the House of Representatives:\n\nAmong the vicissitudes incident to life no event could have filled me with greater anxieties than that of which the notification was transmitted by your order, and received on the 14th day of the present month.'

# %%
def process_speeches(speeches):
  word_tokenized_speeches = list()
  for speech in speeches:
    sentence_tokenizer = PunktSentenceTokenizer()
    sentence_tokenized_speech = sentence_tokenizer.tokenize(speech)
    word_tokenized_sentences = list()
    for sentence in sentence_tokenized_speech:
      word_tokenized_sentence = [word.lower().strip('.').strip('?').strip('!') for word in sentence.replace(",","").replace("-"," ").replace(":","").split()]
      word_tokenized_sentences.append(word_tokenized_sentence)
    word_tokenized_speeches.append(word_tokenized_sentences)
  return word_tokenized_speeches

# %%
# Breakdown the speeches into words on a sentence by sentence basis
processed_speeches = process_speeches(speeches)
# Print 1 sentence of the 1st speech
processed_speeches[0][0]
# Out:
# ['fellow',
#  'citizens',
#  'of',
#  'the',
#  'senate',
#  'and',
#  'of',
#  'the',
#  'house',
#  'of',
#  'representatives',
#  'among',
#  'the',
#  'vicissitudes',
#  'incident',
#  'to',
#  'life',
#  'no',
#  'event',
#  'could',
#  'have',
#  'filled',
#  'me',
#  'with',
#  'greater',
#  'anxieties',
#  'than',
#  'that',
#  'of',
#  'which',
#  'the',
#  'notification',
#  'was',
#  'transmitted',
#  'by',
#  'your',
#  'order',
#  'and',
#  'received',
#  'on',
#  'the',
#  '14th',
#  'day',
#  'of',
#  'the',
#  'present',
#  'month']

# %% [markdown]
# In order to build a custom set of word embeddings using `gensim`, we need to convert our data into a list of lists, where each inner list is a sentence and each item in the inner list is a word token.

# %%
def merge_speeches(speeches):
  all_sentences = list()
  for speech in speeches:
    for sentence in speech:
      all_sentences.append(sentence)
  return all_sentences

# %%
# Create list of lists where each inner list is a sentence and each item in the inner list is a word token
all_sentences = merge_speeches(processed_speeches)
# Print 1 sentence of the 1st speech
all_sentences[0]
# Out:
# ['fellow',
#  'citizens',
#  'of',
#  'the',
#  'senate',
#  'and',
#  'of',
#  'the',
#  'house',
#  'of',
#  'representatives',
#  'among',
#  'the',
#  'vicissitudes',
#  'incident',
#  'to',
#  'life',
#  'no',
#  'event',
#  'could',
#  'have',
#  'filled',
#  'me',
#  'with',
#  'greater',
#  'anxieties',
#  'than',
#  'that',
#  'of',
#  'which',
#  'the',
#  'notification',
#  'was',
#  'transmitted',
#  'by',
#  'your',
#  'order',
#  'and',
#  'received',
#  'on',
#  'the',
#  '14th',
#  'day',
#  'of',
#  'the',
#  'present',
#  'month']

# %% [markdown]
# To make sure we don't analyse common words let's remove them from the dataset.

# %%
# Remove common english words
stop_words = set(stopwords.words('english'))
all_sentences_filtered = [[word for word in sentence if not word in stop_words] for sentence in all_sentences]

# %% [markdown]
# ### Investigating most common
#
# To get a better understanding of the data, let’s take a look at the most frequently used words across all the inaugural addresses.

# %%
def most_frequent_words(list_of_sentences):
  all_words = [word for sentence in list_of_sentences for word in sentence]
  return Counter(all_words).most_common()

# %%
most_freq_words = most_frequent_words(all_sentences_filtered)
most_freq_words
# Out:
# [('government', 575),
#  ('people', 556),
#  ('us', 469),
#  ('upon', 365),
#  ('must', 362),
#  ('great', 336),
#  ('may', 334),
#  ('world', 310),
#  ('states', 309),
#  ('shall', 309),
#  ('every', 299),
#  ('country', 296),
#  ('nation', 288),
#  ('one', 254),
#  ('new', 251),
#  ('peace', 250),
#  ('citizens', 241),
#  ('power', 230),
#  ('public', 221),
#  ('time', 213),
#  ('would', 209),
#  ('constitution', 201),
#  ('united', 198),
#  ('nations', 187),
#  ('america', 184),
#  ('free', 183),
#  ('freedom', 182),
#  ('union', 171),
#  ('war', 168),
#  ('american', 159),
#  ('national', 157),
#  ('made', 155),
#  ('fellow', 149),
#  ('let', 148),
#  ('make', 142),
#  ('good', 141),
#  ('men', 141),
#  ('well', 140),
#  ('years', 138),
#  ('without', 136),
#  ('spirit', 136),
#  ('law', 135),
#  ('life', 134),
#  ('rights', 134),
#  ('justice', 134),
#  ('never', 132),
#  ('congress', 129),
#  ('laws', 128),
#  ('right', 118),
#  ('best', 117),
#  ('duty', 116),
#  ('hope', 116),
#  ('work', 116),
#  ('interests', 113),
#  ('liberty', 112),
#  ('among', 107),
#  ('state', 106),
#  ('many', 105),
#  ('political', 103),
#  ('know', 103),
#  ('foreign', 102),
#  ('long', 101),
#  ('much', 100),
#  ('first', 98),
#  ('executive', 97),
#  ('today', 97),
#  ('history', 96),
#  ('powers', 95),
#  ('part', 95),
#  ('human', 94),
#  ('policy', 94),
#  ('principles', 94),
#  ('future', 93),
#  ('progress', 93),
#  ('within', 91),
#  ('god', 91),
#  ('whole', 90),
#  ('common', 90),
#  ('duties', 89),
#  ('day', 88),
#  ('system', 88),
#  ('president', 88),
#  ('administration', 87),
#  ('far', 87),
#  ('ever', 87),
#  ('faith', 87),
#  ('support', 87),
#  ('man', 86),
#  ('less', 85),
#  ('purpose', 85),
#  ('present', 84),
#  ('confidence', 84),
#  ('service', 83),
#  ('party', 82),
#  ('way', 82),
#  ('necessary', 81),
#  ('together', 81),
#  ('still', 80),
#  ('yet', 80),
#  ('high', 78),
#  ('force', 78),
#  ('old', 78),
#  ('always', 78),
#  ('better', 76),
#  ('come', 76),
#  ('institutions', 75),
#  ('believe', 75),
#  ('equal', 74),
#  ('others', 74),
#  ('strength', 74),
#  ('americans', 74),
#  ('need', 73),
#  ('office', 72),
#  ('interest', 72),
#  ('land', 72),
#  ('could', 71),
#  ('means', 71),
#  ('place', 70),
#  ('general', 70),
#  ('even', 69),
#  ('change', 69),
#  ('home', 69),
#  ('action', 69),
#  ('might', 68),
#  ('federal', 68),
#  ('prosperity', 67),
#  ('find', 67),
#  ('whose', 66),
#  ('give', 66),
#  ('secure', 66),
#  ('things', 66),
#  ('order', 65),
#  ('given', 65),
#  ('security', 65),
#  ('self', 65),
#  ('full', 64),
#  ('republic', 64),
#  ('take', 63),
#  ('proper', 63),
#  ('found', 63),
#  ('commerce', 63),
#  ('true', 63),
#  ('responsibility', 63),
#  ('important', 62),
#  ('subject', 62),
#  ('like', 62),
#  ('business', 62),
#  ('called', 61),
#  ('seek', 61),
#  ('see', 60),
#  ('trust', 59),
#  ('ought', 59),
#  ('character', 59),
#  ('respect', 59),
#  ('since', 59),
#  ('question', 59),
#  ('principle', 59),
#  ('toward', 59),
#  ('earth', 59),
#  ('revenue', 59),
#  ('century', 59),
#  ('honor', 58),
#  ('democracy', 58),
#  ('influence', 57),
#  ('another', 57),
#  ('cause', 57),
#  ('become', 57),
#  ('beyond', 57),
#  ('done', 57),
#  ('civil', 56),
#  ('course', 56),
#  ('protection', 56),
#  ('cannot', 56),
#  ('help', 56),
#  ('however', 55),
#  ('live', 55),
#  ('stand', 55),
#  ('also', 55),
#  ('act', 54),
#  ('past', 54),
#  ('oath', 54),
#  ('authority', 54),
#  ('citizen', 54),
#  ('strong', 54),
#  ('greater', 53),
#  ('meet', 53),
#  ('countrymen', 53),
#  ('love', 52),
#  ('constitutional', 52),
#  ('sense', 52),
#  ('individual', 52),
#  ('economy', 51),
#  ('experience', 51),
#  ('times', 51),
#  ('resources', 50),
#  ('use', 50),
#  ('whether', 50),
#  ('nothing', 49),
#  ('trade', 49),
#  ('purposes', 48),
#  ('governments', 48),
#  ('domestic', 48),
#  ('defense', 48),
#  ('lives', 48),
#  ('effort', 48),
#  ('condition', 48),
#  ('continue', 48),
#  ('labor', 48),
#  ('children', 48),
#  ('control', 48),
#  ('promise', 48),
#  ('economic', 48),
#  ('hand', 47),
#  ('relations', 47),
#  ('opportunity', 47),
#  ('happiness', 46),
#  ('success', 46),
#  ('go', 46),
#  ('maintain', 46),
#  ('two', 46),
#  ('alone', 46),
#  ('regard', 45),
#  ('opinion', 45),
#  ('moral', 45),
#  ('end', 45),
#  ('hands', 44),
#  ('therefore', 44),
#  ('form', 44),
#  ('independence', 44),
#  ('look', 44),
#  ('wisdom', 44),
#  ('ask', 44),
#  ('either', 43),
#  ('fear', 43),
#  ('bring', 43),
#  ('last', 43),
#  ('preserve', 42),
#  ('legislation', 42),
#  ('heart', 42),
#  ('task', 41),
#  ('mind', 41),
#  ('circumstances', 41),
#  ('local', 41),
#  ('say', 41),
#  ('parties', 41),
#  ('desire', 41),
#  ('aid', 41),
#  ('taken', 41),
#  ('measures', 40),
#  ('care', 40),
#  ('thought', 40),
#  ('race', 40),
#  ('welfare', 40),
#  ('fair', 40),
#  ('greatest', 40),
#  ('increase', 40),
#  ('importance', 40),
#  ('ago', 40),
#  ('millions', 40),
#  ('essential', 39),
#  ('affairs', 39),
#  ('blessings', 39),
#  ('possible', 39),
#  ('call', 39),
#  ('favor', 39),
#  ('danger', 39),
#  ('knowledge', 39),
#  ('throughout', 39),
#  ('body', 39),
#  ('making', 39),
#  ('generation', 39),
#  ('peoples', 39),
#  ('hopes', 38),
#  ('exercise', 38),
#  ('highest', 38),
#  ('passed', 38),
#  ('protect', 38),
#  ('courage', 38),
#  ('territory', 38),
#  ('period', 38),
#  ('hold', 38),
#  ('share', 37),
#  ('large', 37),
#  ('judgment', 37),
#  ('require', 37),
#  ('wealth', 37),
#  ('effect', 37),
#  ('safety', 37),
#  ('efforts', 37),
#  ('countries', 37),
#  ('moment', 37),
#  ('civilization', 37),
#  ('questions', 37),
#  ('faithful', 36),
#  ('little', 36),
#  ('chief', 36),
#  ('rule', 36),
#  ('certain', 36),
#  ('object', 36),
#  ('mankind', 36),
#  ('example', 36),
#  ('limits', 36),
#  ('face', 36),
#  ('words', 36),
#  ('forward', 36),
#  ('sufficient', 35),
#  ('nature', 35),
#  ('occasion', 35),
#  ('friends', 35),
#  ('reason', 35),
#  ('view', 35),
#  ('already', 35),
#  ('pledge', 35),
#  ('international', 35),
#  ("america's", 35),
#  ('patriotism', 34),
#  ('destiny', 34),
#  ('permanent', 34),
#  ('thus', 34),
#  ('society', 34),
#  ('existence', 34),
#  ('necessity', 34),
#  ('social', 34),
#  ('population', 34),
#  ('conditions', 34),
#  ('members', 34),
#  ('problems', 34),
#  ('attention', 33),
#  ('solemn', 33),
#  ('abroad', 33),
#  ('obligations', 33),
#  ('powerful', 33),
#  ('carry', 33),
#  ('money', 33),
#  ('back', 33),
#  ('four', 33),
#  ('instrument', 32),
#  ('independent', 32),
#  ('revolution', 32),
#  ('degree', 32),
#  ('wise', 32),
#  ('single', 32),
#  ('produce', 32),
#  ('result', 32),
#  ('speak', 32),
#  ('industry', 32),
#  ('different', 32),
#  ('military', 32),
#  ('expect', 32),
#  ('education', 32),
#  ('fail', 32),
#  ('south', 32),
#  ('industrial', 32),
#  ('women', 32),
#  ('equally', 31),
#  ('promote', 31),
#  ('year', 31),
#  ('wish', 31),
#  ('advance', 31),
#  ('community', 31),
#  ('rather', 31),
#  ('small', 31),
#  ('mr', 31),
#  ('tariff', 31),
#  ('due', 30),
#  ('seen', 30),
#  ('want', 30),
#  ('conduct', 30),
#  ('fact', 30),
#  ('property', 30),
#  ('sound', 30),
#  ('fathers', 30),
#  ('discharge', 30),
#  ('extended', 30),
#  ('clear', 30),
#  ('ideals', 30),
#  ('established', 29),
#  ('none', 29),
#  ('remain', 29),
#  ('personal', 29),
#  ('placed', 29),
#  ('feel', 29),
#  ('often', 29),
#  ('election', 29),
#  ('position', 29),
#  ('portion', 29),
#  ('reach', 29),
#  ('religious', 29),
#  ('lead', 29),
#  ('generations', 29),
#  ('arms', 29),
#  ('dangers', 29),
#  ('away', 29),
#  ('set', 29),
#  ('citizenship', 29),
#  ('almighty', 28),
#  ('consideration', 28),
#  ('honorable', 28),
#  ('presence', 28),
#  ('happy', 28),
#  ('whatever', 28),
#  ('determined', 28),
#  ('humanity', 28),
#  ('extent', 28),
#  ('growth', 28),
#  ('enterprise', 28),
#  ('dignity', 28),
#  ('ability', 28),
#  ('neither', 28),
#  ('responsibilities', 28),
#  ('across', 28),
#  ('objects', 27),
#  ('light', 27),
#  ('endeavor', 27),
#  ('provide', 27),
#  ('mere', 27),
#  ('constant', 27),
#  ('think', 27),
#  ('though', 27),
#  ('peaceful', 27),
#  ('left', 27),
#  ('devotion', 27),
#  ('departments', 27),
#  ('sovereignty', 27),
#  ('feeling', 27),
#  ('turn', 27),
#  ('vast', 27),
#  ('came', 27),
#  ('demands', 27),
#  ('practical', 27),
#  ('cost', 27),
#  ('beginning', 27),
#  ('serve', 27),
#  ('private', 26),
#  ('views', 26),
#  ('honest', 26),
#  ('hearts', 26),
#  ('opinions', 26),
#  ('supreme', 26),
#  ('enough', 26),
#  ('ready', 26),
#  ('keep', 26),
#  ('several', 26),
#  ('legislative', 26),
#  ('equality', 26),
#  ('differences', 26),
#  ('longer', 26),
#  ('put', 26),
#  ('case', 26),
#  ('prevent', 26),
#  ('sacrifice', 26),
#  ('popular', 26),
#  ('cooperation', 26),
#  ('accept', 26),
#  ('material', 26),
#  ('truth', 25),
#  ('sacred', 25),
#  ('harmony', 25),
#  ('perfect', 25),
#  ('secured', 25),
#  ('bear', 25),
#  ('intercourse', 25),
#  ('mutual', 25),
#  ('family', 25),
#  ('needs', 25),
#  ('capacity', 25),
#  ('expression', 25),
#  ('known', 25),
#  ('demand', 25),
#  ('measure', 25),
#  ('patriotic', 25),
#  ('evil', 25),
#  ('obligation', 25),
#  ('merely', 25),
#  ('voice', 24),
#  ('distinguished', 24),
#  ('return', 24),
#  ('department', 24),
#  ('required', 24),
#  ('forms', 24),
#  ('credit', 24),
#  ('majority', 24),
#  ('determination', 24),
#  ('preserved', 24),
#  ('doubt', 24),
#  ('seeking', 24),
#  ("world's", 24),
#  ('improvement', 24),
#  ('conscience', 24),
#  ('afford', 24),
#  ('pay', 24),
#  ('settled', 24),
#  ('complete', 24),
#  ('debt', 24),
#  ('treaty', 24),
#  ('capital', 24),
#  ('defend', 24),
#  ('slavery', 24),
#  ('created', 24),
#  ('remember', 24),
#  ('build', 24),
#  ('methods', 24),
#  ('chosen', 23),
#  ('conflict', 23),
#  ('perhaps', 23),
#  ('deeply', 23),
#  ('parts', 23),
#  ('integrity', 23),
#  ('providence', 23),
#  ('protected', 23),
#  ('difference', 23),
#  ('individuals', 23),
#  ('something', 23),
#  ('formed', 23),
#  ('science', 23),
#  ('leave', 23),
#  ('safe', 23),
#  ('vital', 23),
#  ('wrong', 23),
#  ('matters', 23),
#  ('basis', 23),
#  ('almost', 23),
#  ('forces', 23),
#  ('acts', 23),
#  ('granted', 23),
#  ('reform', 23),
#  ('belief', 23),
#  ('currency', 23),
#  ('special', 23),
#  ('young', 23),
#  ('unity', 23),
#  ('communities', 22),
#  ('benefits', 22),
#  ('effective', 22),
#  ('early', 22),
#  ('number', 22),
#  ('indeed', 22),
#  ('ancient', 22),
#  ('enlightened', 22),
#  ('destruction', 22),
#  ('friendship', 22),
#  ('provided', 22),
#  ('firm', 22),
#  ('said', 22),
#  ('understanding', 22),
#  ('terms', 22),
#  ('wars', 22),
#  ('officers', 22),
#  ('events', 22),
#  ('fully', 22),
#  ('real', 22),
#  ('failure', 22),
#  ('days', 22),
#  ('washington', 22),
#  ("nation's", 22),
#  ('values', 22),
#  ('thank', 22),
#  ('preservation', 21),
#  ('republican', 21),
#  ('experiment', 21),
#  ('instead', 21),
#  ('expenditures', 21),
#  ('express', 21),
#  ('soon', 21),
#  ('value', 21),
#  ('lands', 21),
#  ('choice', 21),
#  ('increasing', 21),
#  ('rich', 21),
#  ('encouragement', 21),
#  ('sometimes', 21),
#  ('deep', 21),
#  ('especially', 21),
#  ('direction', 21),
#  ('strengthen', 21),
#  ('able', 21),
#  ('around', 21),
#  ('point', 21),
#  ('practice', 21),
#  ('navy', 21),
#  ('clearly', 21),
#  ('surely', 21),
#  ('bless', 21),
#  ('living', 21),
#  ('destroy', 21),
#  ('needed', 21),
#  ('poverty', 21),
#  ('hard', 21),
#  ('leadership', 21),
#  ('vision', 21),
#  ('journey', 21),
#  ('health', 20),
#  ('rules', 20),
#  ('seem', 20),
#  ('join', 20),
#  ('side', 20),
#  ('virtue', 20),
#  ('add', 20),
#  ('struggle', 20),
#  ('provision', 20),
#  ('limited', 20),
#  ('requires', 20),
#  ('legitimate', 20),
#  ('chance', 20),
#  ('open', 20),
#  ('encourage', 20),
#  ('agriculture', 20),
#  ('friendly', 20),
#  ('internal', 20),
#  ('consider', 20),
#  ('energy', 20),
#  ('difficulties', 20),
#  ('concern', 20),
#  ('prosperous', 20),
#  ('enter', 20),
#  ('understand', 20),
#  ('age', 20),
#  ('soil', 20),
#  ('reserved', 20),
#  ('resolve', 20),
#  ('path', 20),
#  ('everywhere', 20),
#  ('attempt', 20),
#  ('manner', 20),
#  ('generous', 20),
#  ('development', 20),
#  ('adequate', 20),
#  ('responsible', 20),
#  ('continent', 20),
#  ('tax', 20),
#  ('taxation', 20),
#  ('difficult', 20),
#  ('rest', 20),
#  ('era', 20),
#  ('waste', 19),
#  ('committed', 19),
#  ('former', 19),
#  ('execute', 19),
#  ('functions', 19),
#  ('intelligence', 19),
#  ('adoption', 19),
#  ('operation', 19),
#  ('pride', 19),
#  ('conviction', 19),
#  ('govern', 19),
#  ('enjoy', 19),
#  ('sentiment', 19),
#  ('immediate', 19),
#  ('person', 19),
#  ('taxes', 19),
#  ('extend', 19),
#  ('short', 19),
#  ('amendment', 19),
#  ('follow', 19),
#  ('source', 19),
#  ('results', 19),
#  ('benefit', 19),
#  ('passion', 19),
#  ('continued', 19),
#  ('burden', 19),
#  ('causes', 19),
#  ('army', 19),
#  ('claim', 19),
#  ('price', 19),
#  ('burdens', 19),
#  ('nearly', 19),
#  ('forth', 19),
#  ('confederacy', 19),
#  ('products', 19),
#  ('greatly', 19),
#  ('show', 19),
#  ('sections', 19),
#  ('simple', 19),
#  ('lines', 19),
#  ('achieve', 19),
#  ('higher', 19),
#  ('settlement', 19),
#  ('enforcement', 19),
#  ('dream', 19),
#  ('representatives', 18),
#  ('crisis', 18),
#  ('satisfaction', 18),
#  ('depend', 18),
#  ('least', 18),
#  ('establish', 18),
#  ('suffrage', 18),
#  ('neighbors', 18),
#  ('prescribed', 18),
#  ('various', 18),
#  ('schools', 18),
#  ('europe', 18),
#  ('earnest', 18),
#  ('counsel', 18),
#  ('remains', 18),
#  ('peculiar', 18),
#  ('direct', 18),
#  ('wisely', 18),
#  ('class', 18),
#  ('assume', 18),
#  ('establishment', 18),
#  ('brought', 18),
#  ('branch', 18),
#  ('treasury', 18),
#  ('perform', 18),
#  ('modern', 18),
#  ('recent', 18),
#  ('permit', 18),
#  ('enforce', 18),
#  ('unless', 18),
#  ('democratic', 18),
#  ('dreams', 18),
#  ('lies', 18),
#  ('changes', 18),
#  ('weak', 18),
#  ('born', 18),
#  ('challenge', 18),
#  ('strive', 18),
#  ('vice', 18),
#  ('official', 17),
#  ('sentiments', 17),
#  ('bound', 17),
#  ('expected', 17),
#  ('considered', 17),
#  ('half', 17),
#  ('felt', 17),
#  ('genius', 17),
#  ('idea', 17),
#  ('appear', 17),
#  ('advantage', 17),
#  ('enemies', 17),
#  ('issue', 17),
#  ('restore', 17),
#  ('blood', 17),
#  ('distant', 17),
#  ('declared', 17),
#  ('places', 17),
#  ('false', 17),
#  ('maintained', 17),
#  ('offer', 17),
#  ('existing', 17),
#  ('maintenance', 17),
#  ('precious', 17),
#  ('reasonable', 17),
#  ('proud', 17),
#  ('armed', 17),
#  ('predecessor', 17),
#  ('second', 17),
#  ('strengthened', 17),
#  ('carried', 17),
#  ('sure', 17),
#  ('naval', 17),
#  ('proved', 17),
#  ('respective', 17),
#  ('exist', 17),
#  ('coast', 17),
#  ('held', 17),
#  ('makes', 17),
#  ('productive', 17),
#  ('commercial', 17),
#  ('standards', 17),
#  ('realize', 17),
#  ('create', 17),
#  ('meaning', 17),
#  ('except', 17),
#  ('voices', 17),
#  ('consequences', 16),
#  ('station', 16),
#  ('seems', 16),
#  ('accomplished', 16),
#  ('birth', 16),
#  ('entire', 16),
#  ('advancement', 16),
#  ('divine', 16),
#  ('manufactures', 16),
#  ('dangerous', 16),
#  ('situation', 16),
#  ('elected', 16),
#  ('serious', 16),
#  ('religion', 16),
#  ('founded', 16),
#  ('engaged', 16),
#  ('guidance', 16),
#  ('unite', 16),
#  ('decisions', 16),
#  ('trial', 16),
#  ('offices', 16),
#  ('declaration', 16),
#  ('obvious', 16),
#  ('increased', 16),
#  ('minds', 16),
#  ('drawn', 16),
#  ('cherish', 16),
#  ('standing', 16),
#  ('sides', 16),
#  ('shown', 16),
#  ('production', 16),
#  ('north', 16),
#  ('practicable', 16),
#  ('maintaining', 16),
#  ('organization', 16),
#  ('advantages', 16),
#  ('construction', 16),
#  ('save', 16),
#  ('strict', 16),
#  ('territories', 16),
#  ('relief', 16),
#  ('constantly', 16),
#  ('lasting', 16),
#  ('section', 16),
#  ('reduce', 16),
#  ('subjects', 16),
#  ('forever', 16),
#  ('faithfully', 16),
#  ('rests', 16),
#  ('bonds', 16),
#  ('renew', 16),
#  ('built', 16),
#  ('policies', 16),
#  ('families', 16),
#  ('senate', 15),
#  ('grateful', 15),
#  ('gratitude', 15),
#  ('command', 15),
#  ('exists', 15),
#  ('justly', 15),
#  ('avoid', 15),
#  ('concerns', 15),
#  ('continuance', 15),
#  ('ocean', 15),
#  ('violence', 15),
#  ('western', 15),
#  ('natural', 15),
#  ('pursue', 15),
#  ('authorities', 15),
#  ('answer', 15),
#  ('useful', 15),
#  ('larger', 15),
#  ('foundations', 15),
#  ('discussion', 15),
#  ('heretofore', 15),
#  ('led', 15),
#  ('profound', 15),
#  ('liberal', 15),
#  ('suffering', 15),
#  ('twenty', 15),
#  ('term', 15),
#  ('became', 15),
#  ('pass', 15),
#  ('willing', 15),
#  ('sustained', 15),
#  ('privilege', 15),
#  ('alike', 15),
#  ('suffer', 15),
#  ('belongs', 15),
#  ('performance', 15),
#  ('receive', 15),
#  ('looking', 15),
#  ('wherever', 15),
#  ('privileges', 15),
#  ('controversies', 15),
#  ('ways', 15),
#  ('used', 15),
#  ('move', 15),
#  ('homes', 15),
#  ('balance', 15),
#  ("god's", 15),
#  ('building', 15),
#  ('centuries', 15),
#  ('challenges', 15),
#  ('event', 14),
#  ('decision', 14),
#  ('liberties', 14),
#  ('along', 14),
#  ('particular', 14),
#  ('rewards', 14),
#  ('finally', 14),
#  ('whilst', 14),
#  ('instance', 14),
#  ('actual', 14),
#  ('legislature', 14),
#  ('universal', 14),
#  ('pursued', 14),
#  ('branches', 14),
#  ('cases', 14),
#  ("country's", 14),
#  ('southern', 14),
#  ('fixed', 14),
#  ('greatness', 14),
#  ('successful', 14),
#  ('close', 14),
#  ('limitations', 14),
#  ('devoted', 14),
#  ('entitled', 14),
#  ('believed', 14),
#  ('scarcely', 14),
#  ('likely', 14),
#  ('persons', 14),
#  ('mean', 14),
#  ('written', 14),
#  ('friend', 14),
#  ('intended', 14),
#  ('plans', 14),
#  ('member', 14),
#  ('connected', 14),
#  ('late', 14),
#  ('remedy', 14),
#  ('supported', 14),
#  ('depression', 14),
#  ('knowing', 14),
#  ('session', 14),
#  ('impossible', 14),
#  ('aspirations', 14),
#  ('sectional', 14),
#  ('prejudice', 14),
#  ('promises', 14),
#  ('relation', 14),
#  ('flag', 14),
#  ('cheerfully', 14),
#  ('learned', 14),
#  ('abiding', 14),
#  ('grant', 14),
#  ('matter', 14),
#  ('jurisdiction', 14),
#  ("man's", 14),
#  ('european', 14),
#  ('based', 14),
#  ('fundamental', 14),
#  ('partisan', 14),
#  ('court', 14),
#  ('industries', 14),
#  ('met', 14),
#  ('program', 14),
#  ('helped', 14),
#  ('story', 14),
#  ('weapons', 14),
#  ('difficulty', 13),
#  ('employed', 13),
#  ('consistent', 13),
#  ('feelings', 13),
#  ('adopt', 13),
#  ('separate', 13),
#  ('fire', 13),
#  ('promoted', 13),
#  ('tranquillity', 13),
#  ('certainly', 13),
#  ('arise', 13),
#  ('prepared', 13),
#  ('contributed', 13),
#  ('added', 13),
#  ('abuses', 13),
#  ('preserving', 13),
#  ('disposition', 13),
#  ('adopted', 13),
#  ('sincere', 13),
#  ('pledged', 13),
#  ('declare', 13),
#  ('contest', 13),
#  ('possess', 13),
#  ('thing', 13),
#  ('everything', 13),
#  ('appeal', 13),
#  ('reliance', 13),
#  ('steps', 13),
#  ('road', 13),
#  ('legal', 13),
#  ('taking', 13),
#  ('amount', 13),
#  ('paid', 13),
#  ('surplus', 13),
#  ('injustice', 13),
#  ('narrow', 13),
#  ('fate', 13),
#  ('weight', 13),
#  ('sought', 13),
#  ('generally', 13),
#  ('enjoyed', 13),
#  ('interference', 13),
#  ('provisions', 13),
#  ('observe', 13),
#  ('sympathy', 13),
#  ('next', 13),
#  ('imposed', 13),
#  ('battle', 13),
#  ('happily', 13),
#  ('followed', 13),
#  ('injury', 13),
#  ('blessed', 13),
#  ('pacific', 13),
#  ('markets', 13),
#  ('depends', 13),
#  ('predecessors', 13),
#  ('stability', 13),
#  ('realized', 13),
#  ('language', 13),
#  ('expenditure', 13),
#  ('founders', 13),
#  ('divided', 13),
#  ('mighty', 13),
#  ('learn', 13),
#  ('forbearance', 13),
#  ...]

# %% [markdown]
# ### Word Embedding Models
#
# New we are going to create our first word embedding model that contains word embeddings of all presidents, with `gensim`.

# %%
all_presidents_embeddings = gensim.models.Word2Vec(all_sentences_filtered, window=5, min_count=1, workers=2, sg=1)

# %% [markdown]
# Now that we have our word embeddings, let’s have some fun exploring them. The concept of “freedom” is prevalent in the speeches made by the presidents. Let's find the top 20 words that are used in similar contexts to “freedom”.

# %%
# Find words similar to "freedom"
similar_to_freedom = all_presidents_embeddings.wv.most_similar("freedom", topn=20)
similar_to_freedom
# Out:
# [('human', 0.995997428894043),
#  ('order', 0.9958748817443848),
#  ('history', 0.9955692887306213),
#  ('love', 0.9955539107322693),
#  ('mankind', 0.9955235123634338),
#  ('happiness', 0.9955015778541565),
#  ('come', 0.99549400806427),
#  ('prosperity', 0.9954414367675781),
#  ('lasting', 0.9954339861869812),
#  ('greatest', 0.9953880310058594),
#  ('return', 0.9953851103782654),
#  ('result', 0.9953733682632446),
#  ('greater', 0.995297908782959),
#  ('progress', 0.9952936768531799),
#  ('civilization', 0.9952128529548645),
#  ('promote', 0.9952082633972168),
#  ('advancement', 0.9951228499412537),
#  ('stability', 0.9951140880584717),
#  ('courage', 0.9951120615005493),
#  ('peoples', 0.9951092600822449)]

# %% [markdown]
# What about some controversial terms in human history: "religion" and "God"?

# %%
# Find words similar to "religion"
similar_to_religion = all_presidents_embeddings.wv.most_similar("religion", topn=20)
similar_to_religion
# Out:
# [('real', 0.9990625977516174),
#  ('offer', 0.9990462064743042),
#  ('operation', 0.9990293383598328),
#  ('tranquillity', 0.9989766478538513),
#  ('devoted', 0.9989404678344727),
#  ('show', 0.9989097714424133),
#  ('favored', 0.9988982081413269),
#  ('accomplish', 0.998897910118103),
#  ('abuses', 0.998897135257721),
#  ('railroads', 0.998893141746521),
#  ('expression', 0.9988833069801331),
#  ('crisis', 0.9988784790039062),
#  ('held', 0.9988762140274048),
#  ('necessity', 0.9988740682601929),
#  ('enlightened', 0.9988734722137451),
#  ('purposes', 0.9988724589347839),
#  ('permit', 0.9988663792610168),
#  ('effected', 0.9988657236099243),
#  ('renew', 0.9988641142845154),
#  ('scarcely', 0.9988628029823303)]

# %%
# Find words similar to "God"
similar_to_god = all_presidents_embeddings.wv.most_similar("god", topn=20)
similar_to_god
# Out:
# [('solemn', 0.9954165816307068),
#  ('bless', 0.9951754808425903),
#  ('taken', 0.9945799708366394),
#  ('take', 0.9944190979003906),
#  ('ask', 0.9943535923957825),
#  ('support', 0.9942963719367981),
#  ('suffrages', 0.9941716194152832),
#  ('office', 0.9941268563270569),
#  ('almighty', 0.994091808795929),
#  ('today', 0.9940845966339111),
#  ('confidence', 0.9940605163574219),
#  ('trust', 0.9939019083976746),
#  ('day', 0.9938971400260925),
#  ('entitled', 0.993876039981842),
#  ('friends', 0.993823766708374),
#  ('called', 0.9937983155250549),
#  ('high', 0.9937548637390137),
#  ('portion', 0.9936899542808533),
#  ('distinguished', 0.9936776161193848),
#  ('vice', 0.9936298727989197)]

# %% [markdown]
# Quite a revelation...
#
#
# ### One President
# An interesting aspect of word embeddings is to see how different corpora result in different word embeddings, alluding to differences in how words are used between writers/authors/speakers.
#
# Let’s train a word embedding model on a single president and see how their word embeddings differ from the collection of all presidents. We are going to use President Franklin D. Roosevelt’s speeches as a example here.

# %%
def get_president_sentences(president):
  files = sorted([file for file in os.listdir() if president.lower() in file.lower()])
  speeches = [read_file(file) for file in files]
  processed_speeches = process_speeches(speeches)
  all_sentences = merge_speeches(processed_speeches)
  all_sentences_filtered = [[word for word in sentence if not word in stop_words] for sentence in all_sentences]
  return all_sentences_filtered

# %%
roosevelt_sent = get_president_sentences('Franklin-D-Roosevelt')

# %% [markdown]
# To get a better understanding of President Franklin D Roosevelt’s speeches, let’s take a look at the most frequently used words across his inaugural addresses.

# %%
most_frequent_words(roosevelt_sent)[0:30]
# Out:
# [('nation', 26),
#  ('people', 25),
#  ('government', 23),
#  ('us', 20),
#  ('shall', 20),
#  ('democracy', 20),
#  ('men', 18),
#  ('must', 17),
#  ('know', 16),
#  ('life', 15),
#  ('spirit', 15),
#  ('upon', 13),
#  ('national', 12),
#  ('years', 12),
#  ('may', 12),
#  ('new', 12),
#  ('world', 12),
#  ('every', 11),
#  ('states', 11),
#  ('way', 11),
#  ('good', 11),
#  ('today', 10),
#  ('great', 10),
#  ('power', 10),
#  ('progress', 10),
#  ('old', 10),
#  ('united', 10),
#  ('see', 10),
#  ('time', 9),
#  ('first', 9)]

# %% [markdown]
# Like with our previous word embedding model, let’s explore roosevelt_embeddings! We are going to find the top 20 words that are used in similar contexts to "freedom" and "god".

# %%
roosevelt_embeddings = gensim.models.Word2Vec(roosevelt_sent, window=5, min_count=1, workers=2, sg=1)

# %%
roosevelt_similar_to_freedom = roosevelt_embeddings.wv.most_similar("freedom", topn=20)
roosevelt_similar_to_freedom
# Out:
# [('ideals', 0.3555612564086914),
#  ('challenge', 0.2985445261001587),
#  ('engaging', 0.28151440620422363),
#  ('alike', 0.2713252305984497),
#  ('faithful', 0.27098703384399414),
#  ('employment', 0.26910820603370667),
#  ('secure', 0.25979623198509216),
#  ('elementary', 0.2574740946292877),
#  ('pall', 0.24631841480731964),
#  ('fatalistic', 0.2450205534696579),
#  ('proclaimed', 0.24280594289302826),
#  ('irresistible', 0.2389444261789322),
#  ('experiment', 0.23624424636363983),
#  ('almighty', 0.23192434012889862),
#  ('performance', 0.2289603352546692),
#  ('emerson', 0.22857506573200226),
#  ('remaining', 0.22777263820171356),
#  ('creeds', 0.2275572270154953),
#  ('ahead', 0.2275373935699463),
#  ('recent', 0.2264631986618042)]

# %%
roosevelt_similar_to_god = roosevelt_embeddings.wv.most_similar("god", topn=20)
roosevelt_similar_to_god
# Out:
# [('reason', 0.35487619042396545),
#  ('patchwork', 0.3050941824913025),
#  ('speaks', 0.29313454031944275),
#  ('wage', 0.28905582427978516),
#  ('require', 0.27758654952049255),
#  ('lending', 0.26661258935928345),
#  ('declaration', 0.2642853260040283),
#  ('greatest', 0.25546571612358093),
#  ('away', 0.2506450116634369),
#  ('tried', 0.2505795359611511),
#  ('productiveness', 0.24845187366008759),
#  ('warm', 0.23641154170036316),
#  ('changed', 0.23600950837135315),
#  ("country's", 0.23365409672260284),
#  ('kept', 0.22523440420627594),
#  ('earth', 0.22172710299491882),
#  ('host', 0.22088958323001862),
#  ('translated', 0.2172420769929886),
#  ('move', 0.2169693410396576),
#  ('lines', 0.2168179303407669)]

# %% [markdown]
# The results we see from speeches of one president (even with 4 speeches to work with) compose not enough data to produce robust word embeddings. So in the next section, we will be looking at the speeches of multiple presidents to increase our corpus size and produce better word embeddings.
#
# ### Selection of Presidents
#
# Let’s increase our corpus size and find more defined word embeddings by training a word embedding model on the inaugural addresses of a collection of four presidents featured on Mount Rushmore in Keystone: George Washington, Thomas Jefferson, Theodore Roosevelt, and Abraham Lincoln.

# %%
def get_presidents_sentences(presidents):
  all_sentences = list()
  for president in presidents:
    files = sorted([file for file in os.listdir() if president.lower() in file.lower()])
    speeches = [read_file(file) for file in files]
    processed_speeches = process_speeches(speeches)
    all_prez_sentences = merge_speeches(processed_speeches)
    all_sentences.extend(all_prez_sentences)
    all_sentences_filtered = [[word for word in sentence if not word in stop_words] for sentence in all_sentences]
  return all_sentences_filtered

# %%
rushmore_presidents_sent = get_presidents_sentences(["washington","jefferson","lincoln","theodore-roosevelt"])

# %% [markdown]
# To get a better understanding of President Washington, Jefferson, Lincoln, and Theodore Roosevelt’s speeches, let’s take a look at the most frequently used words across their inaugural addresses.

# %%
most_frequent_words(rushmore_presidents_sent)[0:30]
# Out:
# [('government', 46),
#  ('shall', 42),
#  ('may', 41),
#  ('constitution', 34),
#  ('people', 33),
#  ('us', 32),
#  ('citizens', 30),
#  ('union', 29),
#  ('one', 28),
#  ('public', 28),
#  ('would', 25),
#  ('must', 25),
#  ('every', 24),
#  ('states', 24),
#  ('fellow', 23),
#  ('right', 21),
#  ('law', 20),
#  ('upon', 19),
#  ('state', 18),
#  ('war', 18),
#  ('among', 17),
#  ('good', 17),
#  ('country', 16),
#  ('great', 16),
#  ('power', 16),
#  ('peace', 15),
#  ('present', 14),
#  ('nation', 13),
#  ('let', 13),
#  ('others', 13)]

# %% [markdown]
# Now that we have the sentences from the presidents featured on Mount Rushmore, let's create another word embedding model with gensim.

# %%
rushmore_embeddings = gensim.models.Word2Vec(rushmore_presidents_sent, window=5, min_count=1, workers=2, sg=1)

# %% [markdown]
# Like with our previous word embedding models, let’s explore rushmore_embeddings. We will find words that are used in similar contexts to "freedom" and "god".

# %%
rushmore_similar_to_freedom = rushmore_embeddings.wv.most_similar("freedom", topn=20)
rushmore_similar_to_freedom
# Out:
# [('given', 0.404973566532135),
#  ('shall', 0.40488311648368835),
#  ('union', 0.3774382472038269),
#  ('first', 0.36965152621269226),
#  ('made', 0.36015552282333374),
#  ('power', 0.3592836856842041),
#  ('war', 0.3586719036102295),
#  ('foreign', 0.35098040103912354),
#  ('happiness', 0.34960997104644775),
#  ('treaties', 0.3417947292327881),
#  ('duty', 0.3409098982810974),
#  ('equal', 0.3394305408000946),
#  ('therefore', 0.33861058950424194),
#  ('demanded', 0.33720552921295166),
#  ('every', 0.331023246049881),
#  ('understand', 0.33005741238594055),
#  ('authority', 0.32939761877059937),
#  ('great', 0.32142385840415955),
#  ('pretext', 0.32085418701171875),
#  ('right', 0.3182717263698578)]

# %%
rushmore_similar_to_god = rushmore_embeddings.wv.most_similar("god", topn=20)
rushmore_similar_to_god
# Out:
# [('government', 0.5442899465560913),
#  ('war', 0.5255405306816101),
#  ('public', 0.5180131196975708),
#  ('without', 0.5116174221038818),
#  ('would', 0.49037110805511475),
#  ('may', 0.47593018412590027),
#  ('one', 0.4694865643978119),
#  ('union', 0.4660675525665283),
#  ('us', 0.4656261205673218),
#  ('every', 0.4608868360519409),
#  ('must', 0.4579213559627533),
#  ('shall', 0.4526175856590271),
#  ('constitution', 0.4501025378704071),
#  ('citizens', 0.44717520475387573),
#  ('best', 0.4436720609664917),
#  ('duty', 0.43555450439453125),
#  ('among', 0.4316003620624542),
#  ('present', 0.43008318543434143),
#  ('happiness', 0.4292805790901184),
#  ('nation', 0.42901843786239624)]

# %%
rushmore_similar_to_government = rushmore_embeddings.wv.most_similar("government", topn=20)
rushmore_similar_to_government
# Out:
# [('public', 0.737883448600769),
#  ('union', 0.7208378911018372),
#  ('law', 0.7080079317092896),
#  ('shall', 0.6866411566734314),
#  ('may', 0.6857576370239258),
#  ('would', 0.6808280348777771),
#  ('must', 0.6720712780952454),
#  ('citizens', 0.669371485710144),
#  ('nation', 0.669234037399292),
#  ('national', 0.6657862067222595),
#  ('us', 0.657419741153717),
#  ('one', 0.6548988223075867),
#  ('duty', 0.6467574834823608),
#  ('war', 0.645211398601532),
#  ('best', 0.6441528797149658),
#  ('without', 0.6408768892288208),
#  ('among', 0.6387364864349365),
#  ('people', 0.6376473307609558),
#  ('states', 0.6195920705795288),
#  ('every', 0.6142016649246216)]

# %% [markdown]
# ### Conclusion:
#
# We have trained sets of 'word embeddings' on the whole set and some subsets of inaugural addresses and revealed that presidents as a whole, a "Rushmore group" of presidents and even one particular president use different lexicon and emphasise different things in their speeches. Such common used words for American people as "freedom" and "god" are also used by different groups in different contexts.
